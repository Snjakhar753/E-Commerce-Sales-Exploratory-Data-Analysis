# %% [markdown]
# # <font color=blue> E-Commerce Sales : Exploratory Data Analysis </font>

# %% [markdown]
# ##  -Import Python Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp

# %% [markdown]
# - <font color= green> pandas : for detailed overview of dataset</font>
#
# - <font color=green> numpy : for numerical and mathmatical statistics </font>
# - <font color=green> matplotlib : basic graph (data visualization)</font>
# - <font color=green> seaborn : advanced plot(data visualization)</font>
# - <font color=green> scipy: solving many mathematical equations and algorithms.</font>

# %%
# load data from MS-Excel file
df = pd.read_excel("Superstore_USA.xlsx")

# %% [markdown]
# #  -Data Exloration and Data Overview

# %%
df.shape
# Out:
# (9426, 24)

# %%
df.head(5)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 9421  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423  Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424   Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425   Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %% [markdown]
# - <font color= green> Data type of each columns values</font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %% [markdown]
# # -Missing value analysis

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %% [markdown]
# - <font color= green>Filling missing data with mean :</font>

# %%
df['Product Base Margin']=df['Product Base Margin'].fillna(df['Product Base Margin'].mean())

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - <font color= green> No Duplicate found</found>

# %%
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9426.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %% [markdown]
# - <font color=green> summerized data</font>

# %% [markdown]
# ## - Exploratory Data Analysis

# %% [markdown]
# **<font color= red> Order Priority</font>**

# %%
# Analyise priority of orders of the product
df['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %% [markdown]
# - <font color=green> Data cleaning </font>

# %%
# find the unique values
df['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
df['Order Priority']= df['Order Priority'].replace('Critical ','Critical')

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Order Priority',data=df,color="skyblue")
plt.title("Count of Order Priority")      
plt.show()

# %% [markdown]
# **<font color= red> Shipping Mode </font>**

# %%
# # make a pie chart to show which category has high shiping
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x=df['Ship Mode'].value_counts().index
y=df['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels=x,startangle=90,autopct="%.2f%%")
plt.legend(loc=4)
plt.show()

# %% [markdown]
# - <font color = green>In which shiping mode which category of product and in how much amount</font>

# %%
sns.countplot(x='Ship Mode', data= df,hue='Product Category')
plt.show()

# %% [markdown]
# **<font color= red> Customer Segment </font>**
# - <font color= green>Which level of customer we have mostly  </font>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Customer Segment',data=df,color="skyblue")
plt.title("Level of Customer Segment")
plt.show()

# %% [markdown]
# **<font color= red> Product Category</font>**

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Product Category',data=df,color="skyblue")
plt.show()

# %% [markdown]
# - <font color = green> Office supplies category product is most selling product</font>

# %% [markdown]
# **<font color= red>Product Category & Product SubCategory </font>**

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Product Category',data=df[df["Product Category"]=="Office Supplies"],hue="Product Sub-Category")
plt.show()

# %% [markdown]
# - <font color= green> Paper is hieghest selling product of office supplies category</font>

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Product Category',data=df[df["Product Category"]=="Technology"],hue="Product Sub-Category")
plt.show()

# %% [markdown]
# - <font color= green> Telephones and communication related product is hieghest selling product of office supplies category</font>

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Product Category',data=df[df["Product Category"]=="Furniture"],hue="Product Sub-Category")
plt.show()

# %% [markdown]
# - <font color= green> Office Furniture is hieghest selling product of office supplies category</font>

# %% [markdown]
# **<font color= red> Order Date : Order per Year</font>**

# %%
# New column order year is created to access order year
df['Order_Year']= df['Order Date'].dt.year

# %%
df['Order_Year'].value_counts()
# Out:
# Order_Year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Order_Year',data=df,color="skyblue")
plt.title("Order per Year")
plt.show()

# %% [markdown]
# - <font color= green> Highest Order placed in year 2013</font>

# %% [markdown]
# **<font color=red> State wise order detail </font>**

# %%
 # Top 5 state having highest sales 
top_5=df['State or Province'].value_counts().nlargest(5)
x = top_5.index
y = top_5.values

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='State or Province',data=df,order=x,color="skyblue")
plt.title('Top 5 Highest sales state')
plt.show()

# %% [markdown]
# - <font color = green> highest order placed in California</font>

# %%
least_5=df['State or Province'].value_counts().tail(5)
x = least_5.index
y = least_5.values
least_5
# Out:
# State or Province
# North Dakota    34
# South Dakota    28
# Wyoming         21
# Rhode Island    20
# Delaware        15
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='State or Province',data=df,order=x,color="skyblue")
plt.title("10 low sales state")
plt.show()

# %% [markdown]
# **<font color= red> Profit</font>**

# %%
plt.figure(figsize=(4,4))
sns.barplot(x="Product Category", y="Profit",data=df,estimator="sum",color="skyblue")
plt.title("Profit v/s Product category")
plt.show()

# %% [markdown]
# - <font color=green> Maximum profit obtained in technology category</font>

# %% [markdown]
# **<font color=red> Product Base Margin </font>**

# %%
sns.histplot(df['Product Base Margin'],kde=True)
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.barplot(x="Product Category", y="Product Base Margin",data=df,estimator="sum",color="skyblue")
plt.title("Product Base Margin")
plt.show()

# %% [markdown]
# - *<font color=green> Technology category hase less margin than other but having highest profit </font>*

# %%
# check which product category has highest sales
df_sales=df.groupby('Product Category')['Sales'].sum().reset_index()
df_sales
# Out:
#   Product Category       Sales
# 0        Furniture  3178623.74
# 1  Office Supplies  2258325.55
# 2       Technology  3514982.03

# %%
plt.figure(figsize=(5,4))
sns.barplot(x='Product Category',y='Sales',data=df_sales,color="skyblue")
plt.show()

# %% [markdown]
# ## <font color =blue> Conlusion & Suggestion</font>

# %% [markdown]
# **<font color = "red">Which shipping mode is most frequently utilized for order deliveries?</font>**

# %% [markdown]
# - **<font color="grey"> The shipping mode most frequently utilized for order deliveries is Regular Air,
# which accounts for approximately 74.64% of all deliveries. This suggests that Regular Air is the preferred
# shipping option among customers,indicating its efficiency or popularity in the delivery process.</font>**

# %% [markdown]
# **<font color="grey"> Suggestion : </font>**
#   - **<font color=grey> 1.Since Regular Air is heavily used, negotiate bulk rates with the shipping providers to reduce costs.</font>**
#   - **<font color=grey> 2.Track key performance indicators (KPIs) such as delivery times, customer satisfaction, and shipping costs to identify trends and areas for enhancement.</font>**

# %% [markdown]
# **<font color = red>Which states has highest sales(Top 5) and which has lowest sales(Lowest 5)?</font>**

# %% [markdown]
# - **<font color=grey> The states with the highest sales are California, Texas, Illinois, New York, and Florida.</font>**
# - **<font color=grey> The state with the lowest sales is Delaware, with only 15 units sold. Following Delaware are Rhode Island with 20
# units, Wyoming with 21 units, South Dakota with 28 units, and North Dakota with 34 units.</font>**

# %% [markdown]
# **<font color=grey> Suggestion :</font>**

# %% [markdown]
#  - **<font color= grey> For improve sales in least 5 states we Develop targeted marketing campaigns that address
# the specific needs and preferences of consumers in these states. Utilize local advertising channels,
# social media, and community events to increase brand awareness. </font>**
#  - **<font color=grey> Allocate more resources to high-sales states to further boost sales. This could include
# increased marketing budgets, more sales personnel, and enhanced customer service.</font>**
#  - **<font color=grey> Implement or enhance loyalty programs to retain existing
# customers and encourage repeat purchases. Offer exclusive rewards and benefits for loyal customers.</font>**

# %% [markdown]
# **<font color=red> Which product Category has highest profit and sales </font>**

# %% [markdown]
# - **<font color= grey> The product category with the highest profit and sales is Technology.</font>**
# - **<font color=grey> The product category which has highest profit margin is Office Supplies</font>**

# %% [markdown]
# **<font color=grey> Suggestion :</font>**

# %% [markdown]
# - **<font color= grey> Although Office Supplies have lower sales compared to Technology,
# they yield the highest profit margin, indicating efficient cost management or higher
# markup on items within that category.</font>**
# - **<font color=grey> Create bundle deals that include popular Office Supplies with Technology products.
# This can encourage customers to purchase more Office Supplies along with their Technology needs.</font>**
# - **<font color=grey>Ensure that Office Supplies are prominently featured and easy to find on the company’s
#   website and e-commerce platforms. Use SEO strategies to improve visibility in online searches.</font>**

# %% [markdown]
# # Thank you!
